# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.groupby('Element')['Y2014','Y2015','Y2016', 'Y2017','Y2018'].count()
# Out:
# <ipython-input-25-6d50ac7b3fad>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Element')['Y2014','Y2015','Y2016', 'Y2017','Y2018'].count()
#                                         Y2014  Y2015  Y2016  Y2017  Y2018
# Element
# Domestic supply quantity                 5244   5245   5250   5258   5256
# Export Quantity                          3660   3704   3653   3660   3646
# Fat supply quantity (g/capita/day)       4965   4974   4980   4982   4987
# Feed                                     1216   1177   1215   1213   1225
# Food                                     4896   4901   4910   4912   4913
# Food supply (kcal/capita/day)            4947   4955   4963   4965   4969
# Food supply quantity (kg/capita/yr)      4860   4865   4874   4876   4877
# Import Quantity                          4919   4911   4908   4929   4945
# ...

# %%
df.groupby('Element')['Y2014','Y2015','Y2016', 'Y2017','Y2018'].sum()
# Out:
# <ipython-input-26-720fcafb34b6>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Element')['Y2014','Y2015','Y2016', 'Y2017','Y2018'].sum()
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# ...

# %%
df['Y2014'].isnull().sum()
# Out:
# 1589

# %%
df['Y2014'].isnull().sum()/len(df)
# Out:
# 0.026073544131401474

# %%
df['Y2017'].mean()
# Out:
# 140.9177648602722

# %%
df['Y2017'].std()
# Out:
# 1671.8623590567995

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

x = y[1][1]

x
# Out:
# 8

# %%
#Which of these Areas had the 7th lowest sum in 2017?

df.groupby('Area')['Y2017'].sum().sort_values(ascending=True)[6]
# Out:
# 19102.77

# %%
#Which of these Areas had the highest sum in 2017?
df.groupby('Area')['Y2017'].sum().sort_values(ascending=False)[0]
# Out:
# 1483268.23

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %%
# What is the total sum of Wine produced in 2015 and 2018 respectively?
import numpy as np
d_sum = df.groupby('Item')['Y2015', 'Y2018'].sum()

d_sum
# Out:
# <ipython-input-35-515fb2dc9b3e>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   d_sum = df.groupby('Item')['Y2015', 'Y2018'].sum()
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
# Which year had the least correlation with ‘Element Code’? 
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %% [markdown]
# Answ: 2016

# %%
print
# Out:
# <function print>

# %%
#No of unique ountries
print('Answ:', len(pd.unique(df['Area'])))
# Out:
# Answ: 49

# %% [markdown]
# ## Q.16

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']

pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %% [markdown]
# ## Q. 17

# %%
df.shape
# Out:
# (60943, 12)

# %% [markdown]
# ## Q.18

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-ce1543b3be47> in <module>
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# TypeError: Tuples are immutable

# %% [markdown]
# ## Q.19

# %%
x= np.array([[94, 89, 63],[93, 92, 48],[92, 94, 56]])

x[ : 2, 1 : ]
# Out:
# array([[89, 63],
#        [92, 48]])

# %% [markdown]
# ## Q.20

# %%
# Protein supply quantity in Madagascar in 2015?
pd.DataFrame(df.groupby(['Area', 'Element'])['Y2015'].sum())
# Out:
#                                                     Y2015
# Area     Element
# Algeria  Domestic supply quantity                85972.86
#          Export Quantity                          1104.62
#          Fat supply quantity (g/capita/day)        317.40
#          Feed                                    10308.00
#          Food                                    61693.49
# ...                                                   ...
# Zimbabwe Protein supply quantity (g/capita/day)    175.31
#          Residuals                                -780.00
#          Seed                                      128.00
#          Stock Variation                          -343.00
#          Total Population - Both sexes           13815.00
#
# [803 rows x 1 columns]

# %% [markdown]
# Answ: 172.05
